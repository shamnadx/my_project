# %%
import numpy as np
import pandas as pd

np.random.seed(42)
rows = 20000

df = pd.DataFrame({

    # 🛌 Sleep & Routine
    "sleep_hours": np.round(np.random.uniform(3, 10, rows), 1),
    "sleep_quality": np.random.randint(0, 11, rows),
    "bed_time_period": np.random.choice(
        ["Early", "Normal", "Late"], rows, p=[0.3, 0.5, 0.2]
    ),
    "sleep_consistency": np.random.choice(
        ["Regular", "Irregular"], rows, p=[0.65, 0.35]
    ),
    "nap_minutes": np.random.randint(0, 121, rows),
    "sleep_disturbances": np.random.randint(0, 6, rows),

    # 📱 Digital Habits (CLEANED)
    "screen_time_hours": np.round(np.random.uniform(1, 12, rows), 1),
    "late_night_screen": np.random.choice(["Yes", "No"], rows, p=[0.4, 0.6]),
    "app_usage_type": np.random.choice(
        ["Work", "Social", "Entertainment"], rows, p=[0.35, 0.4, 0.25]
    ),

    # 🍽 Food & Health
    "daily_calories": np.random.randint(1200, 4000, rows),
    "junk_food_servings": np.random.randint(0, 6, rows),
    "healthy_meals_count": np.random.randint(0, 4, rows),
    "water_intake_liters": np.round(np.random.uniform(1, 5, rows), 1),
    "diet_type": np.random.choice(
        ["Vegetarian", "Non-Vegetarian", "Vegan"], rows, p=[0.4, 0.45, 0.15]
    ),
    "meal_timings_regular": np.random.choice(["Yes", "No"], rows, p=[0.6, 0.4]),

    # 🏃 Physical Activity
    "physical_activity_minutes": np.random.randint(0, 180, rows),
    "exercise_type": np.random.choice(
        ["None", "Cardio", "Strength", "Yoga"], rows, p=[0.3, 0.3, 0.25, 0.15]
    ),
    "activity_intensity": np.random.choice(
        ["Low", "Moderate", "High"], rows, p=[0.4, 0.4, 0.2]
    ),

    # 🧠 Mental & Productivity
    "stress_level": np.random.randint(0, 11, rows),
    "focus_level": np.random.randint(0, 11, rows),

    # 🌍 Lifestyle Context
    "occupation_type": np.random.choice(
        ["Student", "Employee", "Freelancer"], rows, p=[0.35, 0.45, 0.2]
    ),
    "outdoor_time_minutes": np.random.randint(0, 240, rows),
    "work_environment": np.random.choice(
        ["Home", "Office", "Hybrid"], rows, p=[0.4, 0.4, 0.2]
    ),
    "habit_streak_days": np.random.randint(0, 120, rows),
    "reward_indulgence": np.random.choice(["Yes", "No"], rows, p=[0.4, 0.6])
})

# 🎯 Habit Quality Score (Regression Target)
habit_score = (
    df.sleep_hours * 6 +
    df.sleep_quality * 4 +
    df.physical_activity_minutes * 0.12 +
    df.healthy_meals_count * 5 +
    df.water_intake_liters * 4 +
    df.focus_level * 3 +
    df.habit_streak_days * 0.2 -
    df.screen_time_hours * 2 -
    df.junk_food_servings * 4 -
    df.stress_level * 3
)

df["habit_quality_score"] = np.clip(
    (habit_score - habit_score.min()) /
    (habit_score.max() - habit_score.min()) * 100,
    0, 100
).round(2)

# Save dataset
df.to_csv("habit_dataset", index=False)

print(df.shape)
print(df.head())
print(df.dtypes)
# Out:
# (20000, 26)
#    sleep_hours  sleep_quality bed_time_period sleep_consistency  nap_minutes  \
# 0          5.6              5          Normal           Regular           82
# 1          9.7              1            Late         Irregular           93
# 2          8.1              3           Early           Regular           83
# 3          7.2              6          Normal           Regular           51
# 4          4.1             10          Normal           Regular           19
#
#    sleep_disturbances  screen_time_hours late_night_screen app_usage_type  \
# 0                   3                6.6               Yes         Social
# 1                   4                1.4               Yes         Social
# 2                   2               11.6               Yes  Entertainment
# 3                   4               11.7               Yes  Entertainment
# 4                   4                9.2               Yes           Work
#
#    daily_calories  ...  exercise_type  activity_intensity  stress_level  \
# 0            3701  ...           Yoga            Moderate             1
# 1            3242  ...         Cardio            Moderate            10
# 2            2374  ...         Cardio                 Low            10
# 3            2068  ...           Yoga            Moderate             1
# 4            1439  ...           None            Moderate             6
#
#   focus_level occupation_type  outdoor_time_minutes work_environment  \
# 0           8        Employee                   192             Home
# 1           9        Employee                   181           Hybrid
# 2           8        Employee                    40           Office
# 3           9      Freelancer                   221             Home
# 4           2         Student                   103           Hybrid
#
#   habit_streak_days  reward_indulgence  habit_quality_score
# 0                38                 No                55.81
# 1               111                Yes                50.35
# 2                26                 No                39.35
# 3                26                Yes                57.97
# 4                29                Yes                44.42
#
# [5 rows x 26 columns]
# sleep_hours                  float64
# sleep_quality                  int64
# bed_time_period               object
# sleep_consistency             object
# nap_minutes                    int64
# sleep_disturbances             int64
# screen_time_hours            float64
# late_night_screen             object
# app_usage_type                object
# daily_calories                 int64
# junk_food_servings             int64
# healthy_meals_count            int64
# water_intake_liters          float64
# diet_type                     object
# meal_timings_regular          object
# physical_activity_minutes      int64
# exercise_type                 object
# activity_intensity            object
# stress_level                   int64
# focus_level                    int64
# occupation_type               object
# outdoor_time_minutes           int64
# work_environment              object
# habit_streak_days              int64
# reward_indulgence             object
# habit_quality_score          float64
# dtype: object

# %%
df
# Out:
#        sleep_hours  sleep_quality bed_time_period sleep_consistency  \
# 0              5.6              5          Normal           Regular
# 1              9.7              1            Late         Irregular
# 2              8.1              3           Early           Regular
# 3              7.2              6          Normal           Regular
# 4              4.1             10          Normal           Regular
# ...            ...            ...             ...               ...
# 19995          9.1              8          Normal           Regular
# 19996          3.3              4           Early           Regular
# 19997          5.1             10          Normal           Regular
# 19998          6.1              8          Normal         Irregular
# 19999          4.2              0          Normal           Regular
#
#        nap_minutes  sleep_disturbances  screen_time_hours late_night_screen  \
# 0               82                   3                6.6               Yes
# 1               93                   4                1.4               Yes
# 2               83                   2               11.6               Yes
# 3               51                   4               11.7               Yes
# 4               19                   4                9.2               Yes
# ...            ...                 ...                ...               ...
# 19995           77                   0                7.5               Yes
# 19996           10                   5                3.0                No
# 19997           11                   5                2.5               Yes
# 19998           82                   3                3.6                No
# 19999           41                   3                3.5               Yes
#
#       app_usage_type  daily_calories  ...  exercise_type  activity_intensity  \
# 0             Social            3701  ...           Yoga            Moderate
# 1             Social            3242  ...         Cardio            Moderate
# 2      Entertainment            2374  ...         Cardio                 Low
# 3      Entertainment            2068  ...           Yoga            Moderate
# 4               Work            1439  ...           None            Moderate
# ...              ...             ...  ...            ...                 ...
# 19995         Social            3429  ...           None                High
# 19996         Social            2080  ...       Strength            Moderate
# 19997         Social            1557  ...         Cardio            Moderate
# 19998         Social            1547  ...           None            Moderate
# 19999           Work            3865  ...       Strength                 Low
#
#        stress_level focus_level occupation_type  outdoor_time_minutes  \
# 0                 1           8        Employee                   192
# 1                10           9        Employee                   181
# 2                10           8        Employee                    40
# 3                 1           9      Freelancer                   221
# 4                 6           2         Student                   103
# ...             ...         ...             ...                   ...
# 19995             0           4      Freelancer                   223
# 19996             6           6         Student                    92
# 19997            10           0        Employee                    75
# 19998             1           9        Employee                   195
# 19999             3           1      Freelancer                   150
#
#       work_environment habit_streak_days  reward_indulgence  \
# 0                 Home                38                 No
# 1               Hybrid               111                Yes
# 2               Office                26                 No
# 3                 Home                26                Yes
# 4               Hybrid                29                Yes
# ...                ...               ...                ...
# 19995             Home                17                 No
# 19996             Home                96                 No
# 19997           Office                96                Yes
# 19998             Home                96                 No
# 19999           Office                62                 No
#
#        habit_quality_score
# 0                    55.81
# 1                    50.35
# 2                    39.35
# 3                    57.97
# 4                    44.42
# ...                    ...
# 19995                71.58
# 19996                39.06
# 19997                51.16
# 19998                77.86
# 19999                47.85
#
# [20000 rows x 26 columns]

# %%
df.shape
# Out:
# (20000, 26)

# %%
df.columns
# Out:
# Index(['sleep_hours', 'sleep_quality', 'bed_time_period', 'sleep_consistency',
#        'nap_minutes', 'sleep_disturbances', 'screen_time_hours',
#        'late_night_screen', 'app_usage_type', 'daily_calories',
#        'junk_food_servings', 'healthy_meals_count', 'water_intake_liters',
#        'diet_type', 'meal_timings_regular', 'physical_activity_minutes',
#        'exercise_type', 'activity_intensity', 'stress_level', 'focus_level',
#        'occupation_type', 'outdoor_time_minutes', 'work_environment',
#        'habit_streak_days', 'reward_indulgence', 'habit_quality_score'],
#       dtype='object')

# %%
df.head()
# Out:
#    sleep_hours  sleep_quality bed_time_period sleep_consistency  nap_minutes  \
# 0          5.6              5          Normal           Regular           82
# 1          9.7              1            Late         Irregular           93
# 2          8.1              3           Early           Regular           83
# 3          7.2              6          Normal           Regular           51
# 4          4.1             10          Normal           Regular           19
#
#    sleep_disturbances  screen_time_hours late_night_screen app_usage_type  \
# 0                   3                6.6               Yes         Social
# 1                   4                1.4               Yes         Social
# 2                   2               11.6               Yes  Entertainment
# 3                   4               11.7               Yes  Entertainment
# 4                   4                9.2               Yes           Work
#
#    daily_calories  ...  exercise_type  activity_intensity  stress_level  \
# 0            3701  ...           Yoga            Moderate             1
# 1            3242  ...         Cardio            Moderate            10
# 2            2374  ...         Cardio                 Low            10
# 3            2068  ...           Yoga            Moderate             1
# 4            1439  ...           None            Moderate             6
#
#   focus_level occupation_type  outdoor_time_minutes work_environment  \
# 0           8        Employee                   192             Home
# 1           9        Employee                   181           Hybrid
# 2           8        Employee                    40           Office
# 3           9      Freelancer                   221             Home
# 4           2         Student                   103           Hybrid
#
#   habit_streak_days  reward_indulgence  habit_quality_score
# 0                38                 No                55.81
# 1               111                Yes                50.35
# 2                26                 No                39.35
# 3                26                Yes                57.97
# 4                29                Yes                44.42
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#        sleep_hours  sleep_quality bed_time_period sleep_consistency  \
# 19995          9.1              8          Normal           Regular
# 19996          3.3              4           Early           Regular
# 19997          5.1             10          Normal           Regular
# 19998          6.1              8          Normal         Irregular
# 19999          4.2              0          Normal           Regular
#
#        nap_minutes  sleep_disturbances  screen_time_hours late_night_screen  \
# 19995           77                   0                7.5               Yes
# 19996           10                   5                3.0                No
# 19997           11                   5                2.5               Yes
# 19998           82                   3                3.6                No
# 19999           41                   3                3.5               Yes
#
#       app_usage_type  daily_calories  ...  exercise_type  activity_intensity  \
# 19995         Social            3429  ...           None                High
# 19996         Social            2080  ...       Strength            Moderate
# 19997         Social            1557  ...         Cardio            Moderate
# 19998         Social            1547  ...           None            Moderate
# 19999           Work            3865  ...       Strength                 Low
#
#        stress_level focus_level occupation_type  outdoor_time_minutes  \
# 19995             0           4      Freelancer                   223
# 19996             6           6         Student                    92
# 19997            10           0        Employee                    75
# 19998             1           9        Employee                   195
# 19999             3           1      Freelancer                   150
#
#       work_environment habit_streak_days  reward_indulgence  \
# 19995             Home                17                 No
# 19996             Home                96                 No
# 19997           Office                96                Yes
# 19998             Home                96                 No
# 19999           Office                62                 No
#
#        habit_quality_score
# 19995                71.58
# 19996                39.06
# 19997                51.16
# 19998                77.86
# 19999                47.85
#
# [5 rows x 26 columns]

# %%
df.isna().sum()
# Out:
# sleep_hours                  0
# sleep_quality                0
# bed_time_period              0
# sleep_consistency            0
# nap_minutes                  0
# sleep_disturbances           0
# screen_time_hours            0
# late_night_screen            0
# app_usage_type               0
# daily_calories               0
# junk_food_servings           0
# healthy_meals_count          0
# water_intake_liters          0
# diet_type                    0
# meal_timings_regular         0
# physical_activity_minutes    0
# exercise_type                0
# activity_intensity           0
# stress_level                 0
# focus_level                  0
# occupation_type              0
# outdoor_time_minutes         0
# work_environment             0
# habit_streak_days            0
# reward_indulgence            0
# habit_quality_score          0
# dtype: int64

# %%
# first of all we need to encode the object types
df.dtypes
# Out:
# sleep_hours                  float64
# sleep_quality                  int64
# bed_time_period               object
# sleep_consistency             object
# nap_minutes                    int64
# sleep_disturbances             int64
# screen_time_hours            float64
# late_night_screen             object
# app_usage_type                object
# daily_calories                 int64
# junk_food_servings             int64
# healthy_meals_count            int64
# water_intake_liters          float64
# diet_type                     object
# meal_timings_regular          object
# physical_activity_minutes      int64
# exercise_type                 object
# activity_intensity            object
# stress_level                   int64
# focus_level                    int64
# occupation_type               object
# outdoor_time_minutes           int64
# work_environment              object
# habit_streak_days              int64
# reward_indulgence             object
# habit_quality_score          float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
df['bed_time_period']=lab.fit_transform(df['bed_time_period'])
df['sleep_consistency']=lab.fit_transform(df['sleep_consistency'])
df['late_night_screen']=lab.fit_transform(df['late_night_screen'])
df['app_usage_type']=lab.fit_transform(df['app_usage_type'])
df['diet_type']=lab.fit_transform(df['diet_type'])
df['meal_timings_regular']=lab.fit_transform(df['meal_timings_regular'])
df['exercise_type']=lab.fit_transform(df['exercise_type'])
df['activity_intensity']=lab.fit_transform(df['activity_intensity'])
df['occupation_type']=lab.fit_transform(df['occupation_type'])
df['work_environment']=lab.fit_transform(df['work_environment'])
df['reward_indulgence']=lab.fit_transform(df['reward_indulgence'])

# %%
df
# Out:
#        sleep_hours  sleep_quality  bed_time_period  sleep_consistency  \
# 0              5.6              5                2                  1
# 1              9.7              1                1                  0
# 2              8.1              3                0                  1
# 3              7.2              6                2                  1
# 4              4.1             10                2                  1
# ...            ...            ...              ...                ...
# 19995          9.1              8                2                  1
# 19996          3.3              4                0                  1
# 19997          5.1             10                2                  1
# 19998          6.1              8                2                  0
# 19999          4.2              0                2                  1
#
#        nap_minutes  sleep_disturbances  screen_time_hours  late_night_screen  \
# 0               82                   3                6.6                  1
# 1               93                   4                1.4                  1
# 2               83                   2               11.6                  1
# 3               51                   4               11.7                  1
# 4               19                   4                9.2                  1
# ...            ...                 ...                ...                ...
# 19995           77                   0                7.5                  1
# 19996           10                   5                3.0                  0
# 19997           11                   5                2.5                  1
# 19998           82                   3                3.6                  0
# 19999           41                   3                3.5                  1
#
#        app_usage_type  daily_calories  ...  exercise_type  activity_intensity  \
# 0                   1            3701  ...              3                   2
# 1                   1            3242  ...              0                   2
# 2                   0            2374  ...              0                   1
# 3                   0            2068  ...              3                   2
# 4                   2            1439  ...              1                   2
# ...               ...             ...  ...            ...                 ...
# 19995               1            3429  ...              1                   0
# 19996               1            2080  ...              2                   2
# 19997               1            1557  ...              0                   2
# 19998               1            1547  ...              1                   2
# 19999               2            3865  ...              2                   1
#
#        stress_level  focus_level  occupation_type  outdoor_time_minutes  \
# 0                 1            8                0                   192
# 1                10            9                0                   181
# 2                10            8                0                    40
# 3                 1            9                1                   221
# 4                 6            2                2                   103
# ...             ...          ...              ...                   ...
# 19995             0            4                1                   223
# 19996             6            6                2                    92
# 19997            10            0                0                    75
# 19998             1            9                0                   195
# 19999             3            1                1                   150
#
#        work_environment  habit_streak_days  reward_indulgence  \
# 0                     0                 38                  0
# 1                     1                111                  1
# 2                     2                 26                  0
# 3                     0                 26                  1
# 4                     1                 29                  1
# ...                 ...                ...                ...
# 19995                 0                 17                  0
# 19996                 0                 96                  0
# 19997                 2                 96                  1
# 19998                 0                 96                  0
# 19999                 2                 62                  0
#
#        habit_quality_score
# 0                    55.81
# 1                    50.35
# 2                    39.35
# 3                    57.97
# 4                    44.42
# ...                    ...
# 19995                71.58
# 19996                39.06
# 19997                51.16
# 19998                77.86
# 19999                47.85
#
# [20000 rows x 26 columns]

# %%
x=df.iloc[:,:-1]
x
# Out:
#        sleep_hours  sleep_quality  bed_time_period  sleep_consistency  \
# 0              5.6              5                2                  1
# 1              9.7              1                1                  0
# 2              8.1              3                0                  1
# 3              7.2              6                2                  1
# 4              4.1             10                2                  1
# ...            ...            ...              ...                ...
# 19995          9.1              8                2                  1
# 19996          3.3              4                0                  1
# 19997          5.1             10                2                  1
# 19998          6.1              8                2                  0
# 19999          4.2              0                2                  1
#
#        nap_minutes  sleep_disturbances  screen_time_hours  late_night_screen  \
# 0               82                   3                6.6                  1
# 1               93                   4                1.4                  1
# 2               83                   2               11.6                  1
# 3               51                   4               11.7                  1
# 4               19                   4                9.2                  1
# ...            ...                 ...                ...                ...
# 19995           77                   0                7.5                  1
# 19996           10                   5                3.0                  0
# 19997           11                   5                2.5                  1
# 19998           82                   3                3.6                  0
# 19999           41                   3                3.5                  1
#
#        app_usage_type  daily_calories  ...  physical_activity_minutes  \
# 0                   1            3701  ...                        170
# 1                   1            3242  ...                         40
# 2                   0            2374  ...                         75
# 3                   0            2068  ...                         14
# 4                   2            1439  ...                         77
# ...               ...             ...  ...                        ...
# 19995               1            3429  ...                         92
# 19996               1            2080  ...                         37
# 19997               1            1557  ...                        160
# 19998               1            1547  ...                         84
# 19999               2            3865  ...                        117
#
#        exercise_type  activity_intensity  stress_level  focus_level  \
# 0                  3                   2             1            8
# 1                  0                   2            10            9
# 2                  0                   1            10            8
# 3                  3                   2             1            9
# 4                  1                   2             6            2
# ...              ...                 ...           ...          ...
# 19995              1                   0             0            4
# 19996              2                   2             6            6
# 19997              0                   2            10            0
# 19998              1                   2             1            9
# 19999              2                   1             3            1
#
#        occupation_type  outdoor_time_minutes  work_environment  \
# 0                    0                   192                 0
# 1                    0                   181                 1
# 2                    0                    40                 2
# 3                    1                   221                 0
# 4                    2                   103                 1
# ...                ...                   ...               ...
# 19995                1                   223                 0
# 19996                2                    92                 0
# 19997                0                    75                 2
# 19998                0                   195                 0
# 19999                1                   150                 2
#
#        habit_streak_days  reward_indulgence
# 0                     38                  0
# 1                    111                  1
# 2                     26                  0
# 3                     26                  1
# 4                     29                  1
# ...                  ...                ...
# 19995                 17                  0
# 19996                 96                  0
# 19997                 96                  1
# 19998                 96                  0
# 19999                 62                  0
#
# [20000 rows x 25 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0        55.81
# 1        50.35
# 2        39.35
# 3        57.97
# 4        44.42
#          ...
# 19995    71.58
# 19996    39.06
# 19997    51.16
# 19998    77.86
# 19999    47.85
# Name: habit_quality_score, Length: 20000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_train
# Out:
#        sleep_hours  sleep_quality  bed_time_period  sleep_consistency  \
# 17218          7.3              5                0                  0
# 15188          4.5              9                2                  1
# 11295          3.1             10                0                  1
# 19772          3.2              4                1                  0
# 13072          4.3              4                0                  1
# ...            ...            ...              ...                ...
# 11284          9.2              9                2                  1
# 11964          6.8              6                0                  1
# 5390           4.0              9                0                  1
# 860            8.4              8                2                  1
# 15795          4.5             10                0                  1
#
#        nap_minutes  sleep_disturbances  screen_time_hours  late_night_screen  \
# 17218          103                   5                2.0                  0
# 15188          106                   3                5.9                  1
# 11295           73                   1               12.0                  0
# 19772           18                   2                2.7                  0
# 13072           85                   2                6.6                  0
# ...            ...                 ...                ...                ...
# 11284           36                   4               11.1                  1
# 11964           85                   3                6.2                  1
# 5390            55                   2                2.3                  0
# 860             40                   1               10.2                  1
# 15795           52                   3                2.9                  0
#
#        app_usage_type  daily_calories  ...  physical_activity_minutes  \
# 17218               2            2134  ...                         99
# 15188               2            3923  ...                        157
# 11295               1            2784  ...                         93
# 19772               0            3722  ...                         55
# 13072               1            3696  ...                        102
# ...               ...             ...  ...                        ...
# 11284               1            2632  ...                         20
# 11964               1            3233  ...                        105
# 5390                1            3953  ...                        156
# 860                 2            1685  ...                          6
# 15795               1            2882  ...                         96
#
#        exercise_type  activity_intensity  stress_level  focus_level  \
# 17218              2                   1             2            1
# 15188              2                   0             9            8
# 11295              3                   1             0            5
# 19772              0                   2             7            6
# 13072              1                   0             5            4
# ...              ...                 ...           ...          ...
# 11284              2                   1             4            7
# 11964              0                   2             3           10
# 5390               3                   2             3            7
# 860                1                   2             0            8
# 15795              1                   1             0            3
#
#        occupation_type  outdoor_time_minutes  work_environment  \
# 17218                2                    30                 2
# 15188                1                   192                 1
# 11295                0                   173                 2
# 19772                0                   229                 1
# 13072                2                   107                 1
# ...                ...                   ...               ...
# 11284                1                   153                 0
# 11964                2                    47                 2
# 5390                 2                   133                 2
# 860                  2                     9                 0
# 15795                1                   182                 0
#
#        habit_streak_days  reward_indulgence
# 17218                 52                  0
# 15188                104                  0
# 11295                116                  0
# 19772                 55                  0
# 13072                  7                  1
# ...                  ...                ...
# 11284                 49                  0
# 11964                 37                  1
# 5390                  21                  1
# 860                   89                  0
# 15795                 39                  1
#
# [14000 rows x 25 columns]

# %%
y_train
# Out:
# 17218    52.01
# 15188    53.20
# 11295    61.14
# 19772    39.04
# 13072    47.14
#          ...
# 11284    55.30
# 11964    66.61
# 5390     54.76
# 860      59.81
# 15795    57.38
# Name: habit_quality_score, Length: 14000, dtype: float64

# %%
x_test
# Out:
#        sleep_hours  sleep_quality  bed_time_period  sleep_consistency  \
# 10650          9.6              4                1                  1
# 2041           6.9              5                0                  1
# 8668           4.8             10                0                  1
# 1114           7.2              9                2                  0
# 13902          7.3              3                0                  1
# ...            ...            ...              ...                ...
# 4464           7.7              2                2                  1
# 15656          5.8              9                1                  1
# 19146          5.0              4                2                  1
# 10567          6.0             10                1                  0
# 9165           8.7              7                2                  1
#
#        nap_minutes  sleep_disturbances  screen_time_hours  late_night_screen  \
# 10650           15                   4               10.2                  0
# 2041            47                   1                7.2                  1
# 8668            46                   1               10.7                  0
# 1114            16                   2                7.4                  0
# 13902           96                   1                3.1                  1
# ...            ...                 ...                ...                ...
# 4464            75                   3                6.8                  0
# 15656           96                   5                3.2                  1
# 19146           32                   4                7.5                  0
# 10567           46                   4               11.8                  1
# 9165            36                   1                7.1                  0
#
#        app_usage_type  daily_calories  ...  physical_activity_minutes  \
# 10650               2            1444  ...                        124
# 2041                1            2445  ...                         81
# 8668                0            2779  ...                        140
# 1114                0            1704  ...                         24
# 13902               2            2920  ...                         21
# ...               ...             ...  ...                        ...
# 4464                2            2435  ...                        156
# 15656               0            1285  ...                         11
# 19146               2            3698  ...                         73
# 10567               2            2060  ...                        143
# 9165                1            3242  ...                        135
#
#        exercise_type  activity_intensity  stress_level  focus_level  \
# 10650              0                   1             9           10
# 2041               2                   1             5            8
# 8668               3                   1             1            4
# 1114               0                   2             7            0
# 13902              2                   1             4            5
# ...              ...                 ...           ...          ...
# 4464               1                   1            10            0
# 15656              0                   1             2            9
# 19146              2                   0             2            7
# 10567              1                   0             2            4
# 9165               0                   1             2           10
#
#        occupation_type  outdoor_time_minutes  work_environment  \
# 10650                2                   109                 0
# 2041                 0                    94                 0
# 8668                 0                   194                 1
# 1114                 1                   130                 2
# 13902                0                    82                 0
# ...                ...                   ...               ...
# 4464                 0                    40                 2
# 15656                0                   237                 2
# 19146                0                    65                 2
# 10567                0                   131                 0
# 9165                 2                   126                 1
#
#        habit_streak_days  reward_indulgence
# 10650                 62                  0
# 2041                  69                  1
# 8668                  42                  0
# 1114                  93                  0
# 13902                 44                  1
# ...                  ...                ...
# 4464                 114                  0
# 15656                 93                  1
# 19146                 55                  0
# 10567                 21                  1
# 9165                  18                  0
#
# [6000 rows x 25 columns]

# %%
y_test
# Out:
# 10650    60.80
# 2041     55.87
# 8668     62.67
# 1114     56.05
# 13902    50.01
#          ...
# 4464     33.75
# 15656    74.25
# 19146    42.05
# 10567    62.35
# 9165     79.64
# Name: habit_quality_score, Length: 6000, dtype: float64

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([60.7959326 , 55.86762539, 62.67428782, ..., 42.05222084,
#        62.35139692, 79.64066712], shape=(6000,))

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R2 Score:", r2)
# Out:
# R2 Score: 0.99999995342867

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)
# Out:
# MAE: 0.0024880509075574475

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print("MSE:", mse)
# Out:
# MSE: 8.305321888425161e-06

# %%
import numpy as np

rmse = np.sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 0.0028818955373894387

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print("R2 Score:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score: 0.99999995342867
# MAE: 0.0024880509075574475
# MSE: 8.305321888425161e-06
# RMSE: 0.0028818955373894387

# %%
#model creation
from sklearn.tree import DecisionTreeRegressor
model1=DecisionTreeRegressor()
model1.fit(x_train,y_train)
y_pred1=model1.predict(x_test)
y_pred1
# Out:
# array([61.28, 58.15, 59.42, ..., 45.61, 67.62, 83.58], shape=(6000,))

# %%
decision_r2= r2_score(y_test, y_pred1)
print("R2 Score:",decision_r2)
# Out:
# R2 Score: 0.6510015147838526

# %%
decision_mae = mean_absolute_error(y_test, y_pred1)
print("MAE:",decision_mae)
# Out:
# MAE: 6.293276666666667

# %%
from sklearn.metrics import mean_squared_error

decision_mse = mean_squared_error(y_test, y_pred1)
print("MSE:",decision_mse)
# Out:
# MSE: 62.23882283333334

# %%
import numpy as np

decision_rmse = np.sqrt(mse)
print("RMSE:",decision_rmse)
# Out:
# RMSE: 0.0028818955373894387

# %%
# Random Forest
from sklearn.ensemble import RandomForestRegressor
random_forest=RandomForestRegressor(n_estimators=100)
random_forest.fit(x_train,y_train)
y_pred2=random_forest.predict(x_test)
y_pred2
# Out:
# array([58.157 , 56.1114, 54.48  , ..., 45.6368, 55.7756, 76.1976],
#       shape=(6000,))

# %%
random_r2= r2_score(y_test, y_pred2)
print("R2 Score:",random_r2)
# Out:
# R2 Score: 0.892793305163231

# %%
random_mae = mean_absolute_error(y_test, y_pred2)
print("MAE:",random_mae)
# Out:
# MAE: 3.5293051999999996

# %%
from sklearn.metrics import mean_squared_error

random_mse = mean_squared_error(y_test, y_pred2)
print("MSE:",random_mse)
# Out:
# MSE: 19.11876059393333

# %%
import numpy as np

random_rmse = np.sqrt(random_mse)
print("RMSE:",random_rmse)
# Out:
# RMSE: 4.372500496733343
